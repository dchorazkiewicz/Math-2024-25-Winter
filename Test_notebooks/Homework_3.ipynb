# %% [markdown]
# <a href="https://colab.research.google.com/github/Erencan2005/Math-2024-25-Winter/blob/main/Test_notebooks/Homework_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 3. Determinants using Laplace's Expansion

# %% [markdown]
# To calculate the determinants of the given matrices using Laplace's expansion:
#
# ### Matrix A:
# $$
# \mathbf{A} =
# \begin{pmatrix}
# 2 & 3 & 1 \\
# 1 & 4 & 0 \\
# 3 & 2 & 1
# \end{pmatrix}
# $$
# Expanding along the first row:
# $$
# \text{det}(\mathbf{A}) = 2
# \begin{vmatrix}
# 4 & 0 \\
# 2 & 1
# \end{vmatrix}
# - 3
# \begin{vmatrix}
# 1 & 0 \\
# 3 & 1
# \end{vmatrix}
# + 1
# \begin{vmatrix}
# 1 & 4 \\
# 3 & 2
# \end{vmatrix}
# $$
# Calculate each minor:
# $$
# \begin{vmatrix}
# 4 & 0 \\
# 2 & 1
# \end{vmatrix} = (4)(1) - (0)(2) = 4
# $$
# $$
# \begin{vmatrix}
# 1 & 0 \\
# 3 & 1
# \end{vmatrix} = (1)(1) - (0)(3) = 1
# $$
# $$
# \begin{vmatrix}
# 1 & 4 \\
# 3 & 2
# \end{vmatrix} = (1)(2) - (4)(3) = 2 - 12 = -10
# $$
# Substitute back:
# $$
# \text{det}(\mathbf{A}) = 2(4) - 3(1) + 1(-10) = 8 - 3 - 10 = -5
# $$
#
# ### Matrix B:
# $$
# \mathbf{B} =
# \begin{pmatrix}
# 2 & 3 & 1 \\
# 1 & 4 & 0 \\
# 3 & 2 & 0
# \end{pmatrix}
# $$
# Expanding along the first row:
# $$
# \text{det}(\mathbf{B}) = 2
# \begin{vmatrix}
# 4 & 0 \\
# 2 & 0
# \end{vmatrix}
# - 3
# \begin{vmatrix}
# 1 & 0 \\
# 3 & 0
# \end{vmatrix}
# + 1
# \begin{vmatrix}
# 1 & 4 \\
# 3 & 2
# \end{vmatrix}
# $$
# Calculate each minor:
# $$
# \begin{vmatrix}
# 4 & 0 \\
# 2 & 0
# \end{vmatrix} = (4)(0) - (0)(2) = 0
# $$
# $$
# \begin{vmatrix}
# 1 & 0 \\
# 3 & 0
# \end{vmatrix} = (1)(0) - (0)(3) = 0
# $$
# $$
# \begin{vmatrix}
# 1 & 4 \\
# 3 & 2
# \end{vmatrix} = -10 \quad \text{(from Matrix A)}
# $$
# Substitute back:
# $$
# \text{det}(\mathbf{B}) = 2(0) - 3(0) + 1(-10) = -10
# $$
#
# ### Matrix C:
# $$
# \mathbf{C} =
# \begin{pmatrix}
# 2 & 3 & 1 & 4 \\
# 1 & 0 & 0 & 6 \\
# 3 & 2 & 1 & 5 \\
# 2 & 1 & 4 & 0
# \end{pmatrix}
# $$
# Expanding along the first row:
# $$
# \text{det}(\mathbf{C}) = 2
# \begin{vmatrix}
# 0 & 0 & 6 \\
# 2 & 1 & 5 \\
# 1 & 4 & 0
# \end{vmatrix}
# - 3
# \begin{vmatrix}
# 1 & 0 & 6 \\
# 3 & 1 & 5 \\
# 2 & 4 & 0
# \end{vmatrix}
# + 1
# \begin{vmatrix}
# 1 & 0 & 6 \\
# 3 & 2 & 5 \\
# 2 & 1 & 0
# \end{vmatrix}
# - 4
# \begin{vmatrix}
# 1 & 0 & 0 \\
# 3 & 2 & 1 \\
# 2 & 1 & 4
# \end{vmatrix}
# $$
# (Solve each determinant step-by-step. Due to space limitations, this will be left for later if needed.)
#
# ### Matrix D:
# $$
# \mathbf{D} =
# \begin{pmatrix}
# 2 & 3 & 1 & 4 & 5 \\
# 1 & 4 & 0 & 0 & 7 \\
# 3 & 0 & 0 & 0 & 0 \\
# 2 & 1 & 4 & 3 & 2 \\
# 1 & 2 & 3 & 4 & 5
# \end{pmatrix}
# $$
# Expanding along the first row:
# $$
# \text{det}(\mathbf{D}) = 2
# \begin{vmatrix}
# 4 & 0 & 0 & 7 \\
# 0 & 0 & 0 & 0 \\
# 1 & 4 & 3 & 2 \\
# 2 & 3 & 4 & 5
# \end{vmatrix}
# - 3
# \begin{vmatrix}
# 1 & 0 & 0 & 7 \\
# 3 & 0 & 0 & 0 \\
# 2 & 4 & 3 & 2 \\
# 1 & 3 & 4 & 5
# \end{vmatrix}
# + \dots
# $$
# (Solve step-by-step as needed.)
